# %%
# !python run.py --model TinyTimeMixer --normalization RevIN --decoder_mode common_channel \
  --dataset ECL --seq_len 512 --pred_len 96 \
  --online_method Proceed --concept_dim 200 --bottleneck_dim 32 \
  --online_learning_rate 0.001 --itr 1
