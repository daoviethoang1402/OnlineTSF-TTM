# %%
filename='./logs/ETTh1_TinyTimeMixer_Proceed.log'

# !python run.py --model TinyTimeMixer --normalization RevIN --decoder_mode mix_channel \
  --dataset ETTh1 --seq_len 512 --pred_len 96 --freq h \
  --online_method Proceed --concept_dim 200 --bottleneck_dim 32 --batch_size 64 \
  --online_learning_rate 0.0001 --itr 1 >> {filename} 2>&1
