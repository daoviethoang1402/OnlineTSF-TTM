# %%
# !python run.py --model TinyTimeMixer --normalization RevIN --decoder_mode mix_channel \
  --dataset ETTh2 --seq_len 512 --pred_len 96 \
  --online_method Proceed --concept_dim 200 --bottleneck_dim 32 \
  --online_learning_rate 0.0001 --itr 1
# Out:
# 2026-06-01 20:45:36
# Args in experiment:
# ...

# %%
# !python run.py --model TinyTimeMixer --normalization RevIN --decoder_mode mix_channel \
  --dataset ETTh2 --seq_len 512 --pred_len 96 --batch_size 64\
  --online_method Proceed --concept_dim 200 --bottleneck_dim 32 \
  --online_learning_rate 0.001 --itr 1
