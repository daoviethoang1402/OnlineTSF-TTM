# %%
# !python3 -u run.py \
  --model TinyTimeMixer \
  --online_method Proceed \
  --dataset ETTh1 \
  --normalization RevIN \
  --seq_len 512 \
  --pred_len 96 \
  --online_learning_rate 0.0001 \
  --itr 1
# Out:
# 2026-05-17 23:07:21
# Args in experiment:
# ...
