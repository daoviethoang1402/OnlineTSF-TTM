# %%
# !python3 -u run.py \
  --model PatchTST \
  --online_method Proceed \
  --dataset ETTh1 \
  --normalization RevIN \
  --seq_len 512 \
  --pred_len 96 \
  --online_learning_rate 0.0001 \
  --itr 1
# Out:
# 2026-05-25 15:35:13
# Args in experiment:
# ...

# %%
# !python run.py --model TinyTimeMixer --dataset ETTh1 --seq_len 512 --pred_len 96 \
  --online_method Proceed --concept_dim 200 --bottleneck_dim 32 \
  --online_learning_rate 0.0001
# Out:
# 2026-05-30 17:37:18
# Args in experiment:
# ...

# %%
# !python run.py --model TinyTimeMixer --dataset ETTh1 --seq_len 512 --pred_len 96 \
  --online_method Proceed --concept_dim 200 --bottleneck_dim 32 \
  --online_learning_rate 0.0001 --pretrain
